# %% [markdown]
# # Primer Notbook
# ## Luisa Valencia - 1004921468

# %% [markdown]
# # Asignación

# %% [markdown]
# ### 1. Cargar un archivo de excel (con una ruta permenanate en drive)

# %%
ubi_archivo = '/content/clase1_CE.xlsx'
'/content/drive/MyDrive/1 UN/1 SEMESTRES/11 Semestre 2022-I 🖐🏼🖐🏼👆🏼/Computación Estadística/Clases/Clase 1/clase1_CE.xlsx'
# Out:
# '/content/drive/MyDrive/1 UN/1 SEMESTRES/11 Semestre 2022-I 🖐🏼🖐🏼👆🏼/Computación Estadística/Clases/Clase 1/clase1_CE.xlsx'

# %% [markdown]
# ### 2. colocar una imagen desde internet

# %% [markdown]
# ![](https://rstudio.github.io/reticulate/images/reticulated_python.png)

# %% [markdown]
# ### 3. Escribir una matrix 4x4 (en $\LaTeX$)

# %% [markdown]
# $$\begin{bmatrix}
#  x_1& y_1& z_1& w_1 \\
#  x_2& y_2& z_2& w_2 \\
#  x_3& y_3& z_3& w_3 \\
#  x_4& y_4& z_4& w_4 \\
# \end{bmatrix}$$

# %% [markdown]
# ### 4. ¿Como crear un tabla? (en $\LaTeX$)

# %% [markdown]
# $$\begin{array}{|c|c|} \hline
# Fruta & Cantidad \\ \hline
# Manzana & 10 \\
# Kiwi & 7 \\
# Uva & 4 \\ \hline
# \end{array}$$

# %% [markdown]
# ### 5. Copiar una ecuación estadistica (en $\LaTeX$)

# %% [markdown]
# $$b=\frac{\sum xy - \frac{\left ( \sum x \right )\left ( \sum y \right )}{n}}{\sum x^{2}-\frac{\left ( \sum x \right )^{2}}{n}}$$
